# %% [markdown]
# In this project we will create a Convolutional Neural Network which will be able to predict whether a plant is suffering from a disease. We will use different layers and other hyperparameters for building, training and testing this classifictaion model.We will be using tensorflow and keras for this project.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
from sklearn.preprocessing import label_binarize,  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from keras.models import model_from_json
from tensorflow.keras.utils import to_categorical

# %%
#Now we will observe some of the iamges that are their in our dataset. We will plot 16 images here using the matplotlib library.
plt.figure(figsize=(12,12))
path = "../input/leaf-image-dataset/Plant_images/Potato___Early_blight"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)#height of image

# %% [markdown]
# After visualizing the images let us move forward and create a function which will convert the images into a numpy array. It is required because we will normalize our dataset after this.

# %%
#Converting Images to array 
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256,256))
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
dir = "../input/leaf-image-dataset/Plant_images"
root_dir = listdir(dir)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0,1,2]
temp = -1

# Reading and converting image to numpy array
#Now we will convert all the images into numpy array.

for directory in root_dir:
  plant_image_list = listdir(f"{dir}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dir}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %% [markdown]
# Now we will convert all the images into numpy array.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()

#it is a balanced dataset as you can see
# Out:
# 0    300
# 1    300
# 2    300
# dtype: int64

# %%
#Next we will observe the shape of the image.
image_list[0].shape
# Out:
# (256, 256, 3)

# %%
#Checking the total number of the images which is the length of the labels list.
label_list = np.array(label_list)
label_list.shape
# Out:
# (900,)

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %%
#Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 256,256,3)
x_test = x_test.reshape( -1, 256,256,3)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel).

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(8, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 85, 85, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 85, 85, 16)        4624
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 42, 42, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 28224)             0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 225800
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 27
# =================================================================
# Total params: 231,347
# Trainable params: 231,347
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Binary Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

# %%
#Next we will split the dataset into validation and training data.
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, 
                    validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 8s 1s/step - loss: 1.0658 - accuracy: 0.3420 - val_loss: 1.0357 - val_accuracy: 0.3333
# Epoch 2/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.9925 - accuracy: 0.4670 - val_loss: 0.9523 - val_accuracy: 0.5486
# Epoch 3/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.9089 - accuracy: 0.5990 - val_loss: 0.8782 - val_accuracy: 0.5694
# Epoch 4/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.8271 - accuracy: 0.6545 - val_loss: 0.7932 - val_accuracy: 0.6250
# Epoch 5/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.7398 - accuracy: 0.6719 - val_loss: 0.7236 - val_accuracy: 0.6319
# Epoch 6/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.6686 - accuracy: 0.6684 - val_loss: 0.6675 - val_accuracy: 0.6528
# Epoch 7/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.6091 - accuracy: 0.6771 - val_loss: 0.6123 - val_accuracy: 0.6458
# Epoch 8/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.5530 - accuracy: 0.6771 - val_loss: 0.5639 - val_accuracy: 0.6528
# Epoch 9/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.5099 - accuracy: 0.6771 - val_loss: 0.5263 - val_accuracy: 0.6528
# Epoch 10/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.4757 - accuracy: 0.6771 - val_loss: 0.5042 - val_accuracy: 0.6528
# Epoch 11/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.4552 - accuracy: 0.6771 - val_loss: 0.4784 - val_accuracy: 0.6528
# Epoch 12/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.4360 - accuracy: 0.6771 - val_loss: 0.4625 - val_accuracy: 0.6597
# Epoch 13/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.4218 - accuracy: 0.6771 - val_loss: 0.4454 - val_accuracy: 0.6597
# Epoch 14/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.4075 - accuracy: 0.6806 - val_loss: 0.4338 - val_accuracy: 0.6667
# Epoch 15/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.3976 - accuracy: 0.6771 - val_loss: 0.4235 - val_accuracy: 0.6667
# Epoch 16/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.3865 - accuracy: 0.6858 - val_loss: 0.4109 - val_accuracy: 0.6736
# Epoch 17/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.3777 - accuracy: 0.6892 - val_loss: 0.4019 - val_accuracy: 0.6806
# Epoch 18/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.3687 - accuracy: 0.6997 - val_loss: 0.3926 - val_accuracy: 0.6875
# Epoch 19/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.3609 - accuracy: 0.7118 - val_loss: 0.3831 - val_accuracy: 0.7014
# Epoch 20/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.3531 - accuracy: 0.7153 - val_loss: 0.3851 - val_accuracy: 0.7014
# Epoch 21/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.3507 - accuracy: 0.7274 - val_loss: 0.3710 - val_accuracy: 0.7014
# Epoch 22/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.3420 - accuracy: 0.7188 - val_loss: 0.3686 - val_accuracy: 0.7222
# Epoch 23/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.3340 - accuracy: 0.7378 - val_loss: 0.3518 - val_accuracy: 0.7292
# Epoch 24/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.3257 - accuracy: 0.7483 - val_loss: 0.3362 - val_accuracy: 0.7431
# Epoch 25/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.2900 - accuracy: 0.8299 - val_loss: 0.2705 - val_accuracy: 0.9861
# Epoch 26/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.2244 - accuracy: 0.9705 - val_loss: 0.1934 - val_accuracy: 0.9653
# Epoch 27/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1652 - accuracy: 0.9878 - val_loss: 0.1575 - val_accuracy: 0.9861
# Epoch 28/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1325 - accuracy: 0.9861 - val_loss: 0.1603 - val_accuracy: 0.9583
# Epoch 29/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.1189 - accuracy: 0.9844 - val_loss: 0.1183 - val_accuracy: 0.9931
# Epoch 30/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0998 - accuracy: 0.9931 - val_loss: 0.1050 - val_accuracy: 0.9931
# Epoch 31/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.0859 - accuracy: 0.9931 - val_loss: 0.0922 - val_accuracy: 1.0000
# Epoch 32/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0792 - accuracy: 0.9931 - val_loss: 0.0843 - val_accuracy: 0.9931
# Epoch 33/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0741 - accuracy: 0.9948 - val_loss: 0.0845 - val_accuracy: 0.9931
# Epoch 34/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0685 - accuracy: 0.9913 - val_loss: 0.0740 - val_accuracy: 1.0000
# Epoch 35/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0642 - accuracy: 0.9931 - val_loss: 0.0819 - val_accuracy: 0.9861
# Epoch 36/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0590 - accuracy: 0.9948 - val_loss: 0.0632 - val_accuracy: 1.0000
# Epoch 37/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.0525 - accuracy: 0.9983 - val_loss: 0.0658 - val_accuracy: 0.9861
# Epoch 38/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0477 - accuracy: 0.9948 - val_loss: 0.0526 - val_accuracy: 1.0000
# Epoch 39/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0449 - accuracy: 0.9948 - val_loss: 0.0519 - val_accuracy: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0419 - accuracy: 0.9983 - val_loss: 0.0477 - val_accuracy: 1.0000
# Epoch 41/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0405 - accuracy: 0.9965 - val_loss: 0.0445 - val_accuracy: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0366 - accuracy: 0.9965 - val_loss: 0.0434 - val_accuracy: 1.0000
# Epoch 43/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.0353 - accuracy: 0.9983 - val_loss: 0.0395 - val_accuracy: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0331 - accuracy: 0.9983 - val_loss: 0.0419 - val_accuracy: 0.9931
# Epoch 45/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0312 - accuracy: 0.9983 - val_loss: 0.0359 - val_accuracy: 1.0000
# Epoch 46/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0325 - accuracy: 0.9948 - val_loss: 0.0362 - val_accuracy: 1.0000
# Epoch 47/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0277 - accuracy: 0.9983 - val_loss: 0.0346 - val_accuracy: 1.0000
# Epoch 48/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0264 - accuracy: 0.9983 - val_loss: 0.0320 - val_accuracy: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.0255 - accuracy: 0.9983 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 50/50
# 5/5 [==============================] - 5s 1s/step - loss: 0.0242 - accuracy: 0.9983 - val_loss: 0.0302 - val_accuracy: 1.0000

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0510 - accuracy: 0.9889
# Test Accuracy: 98.88888597488403

# %%
y_pred = model.predict(x_test)

# %%
# Plotting image to compare
img = array_to_img(x_test[0])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x723342241FD0>

# %%
# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",all_labels[np.argmax(y_test[0])])
print("Predicted : ",all_labels[np.argmax(y_pred[0])])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight
